# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("./basic_test/result.csv")

i = "loss_on_full_trainset"
j = "gradient_norm_on_full_trainset"
end = 6000

plt.plot(df1[i][:end], label="loss_on_full_trainset")
plt.plot(df1[j][:end], label="gradient_norm_on_full_trainset")
plt.title("rho=0,uniform data,lr=0.8")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()

# %%
df1 = pd.read_csv("./basic_test/result_异质性数据_uniform_lr.csv")

i = "loss_on_full_trainset"
j = "gradient_norm_on_full_trainset"
end = 6000

plt.plot(df1[i][:end], label="loss_on_full_trainset")
plt.plot(df1[j][:end], label="gradient_norm_on_full_trainset")
plt.title("rho=0,hetero data,lr=0.8")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()

# %%
df1 = pd.read_csv("./result_differ_lr_and_hetero/a_inverse_exp_hetero_alpha0.1_lr_basic=0.8.csv")
df2 = pd.read_csv("./result_differ_lr_and_hetero/random_max_exp_hetero_alpha0.1_lr_basic=0.8.csv")
df3 = pd.read_csv("./result_differ_lr_and_hetero/vertex_max_exp_hetero_alpha0.1_lr_basic=0.8.csv")
df4 = pd.read_csv("./result_differ_lr_and_hetero/vertex_min_exp_hetero_alpha0.1_lr_basic=0.8.csv")

i = "loss_on_full_trainset"
j = "gradient_norm_on_full_trainset"
end = 120
plt.plot(df1[i][:end], label="a_inverse")
plt.plot(df2[i][:end], label="random_max")
plt.plot(df3[i][:end], label="vertex_max")
plt.plot(df4[i][:end], label="vertex_min")
plt.title("LOSS,rho=0,hetero data,lr_basic=0.8")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()

i = "loss_on_full_trainset"
j = "gradient_norm_on_full_trainset"
end = 12000000
plt.plot(df1[j][:end], label="a_inverse")
plt.plot(df2[j][:end], label="random_max")
plt.plot(df3[j][:end], label="vertex_max")
plt.plot(df4[j][:end], label="vertex_min")
plt.title("GRADIENT NORM,rho=0,hetero data,lr_basic=0.8")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()

# %%
df1 = pd.read_csv("./result_differ_lr_and_hetero/vertex_min_exp_hetero_alpha0.1_lr_basic=0.8.csv")

i = "loss_on_full_trainset"
j = "gradient_norm_on_full_trainset"
end = 6000

plt.plot(df1[i][:end], label="loss_on_full_trainset")
plt.plot(df1[j][:end], label="gradient_norm_on_full_trainset")
plt.title("rho=0.1,hetero data,lr=0.8, vertex")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()

# %%
df1 = pd.read_csv("/Users/luogan/Code/new_push_pull/合成数据_不使用cupy_最简单的版本/MNIST/testhetero=True, alpha=0.1, PushPull, lr[0]=0.005, n_nodes=4, batch_size=128, 2025-07-30.csv")
df2 = pd.read_csv("/Users/luogan/Code/new_push_pull/合成数据_不使用cupy_最简单的版本/MNIST/testhetero=True, alpha=0.1, PushPull, lr[0]=0.08, n_nodes=4, batch_size=128, 2025-07-30.csv")

i = "consensus_per_epoch"
j = "gradient_norm_on_full_trainset"
end = 60000

plt.plot(df1[i][:end], label="uniform lr")
plt.plot(df2[i][:end], label="vertex lr")
plt.title("consensus, mnist, n=4, lr_basic=5e-3")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()


i = "grad_norm_per_epoch"
end = 60000

plt.plot(df1[i][:end], label="uniform lr")
plt.plot(df2[i][:end], label="vertex lr")
plt.title("grad_norm, mnist, n=4, lr_basic=5e-3")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()


i = "test_accuracy(average)"
end = 60000

plt.plot(df1[i][:end], label="uniform lr")
plt.plot(df2[i][:end], label="vertex lr")
plt.title("test_accuracy(average), mnist, n=4, lr_basic=5e-3")
plt.grid()
plt.legend()
plt.show()


i = "test_loss(average)"
end = 60000

plt.plot(df1[i][:end], label="uniform lr")
plt.plot(df2[i][:end], label="vertex lr")
plt.title("test_loss(average), mnist, n=4, lr_basic=5e-3")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()

# %%
df1 = pd.read_csv("/Users/luogan/Code/new_push_pull/合成数据_不使用cupy_最简单的版本/MNIST/testgrad_norm,hetero=True,s alpha=0.1, PushPull, lr[0]=0.005, n_nodes=4, batch_size=128, 2025-07-30.csv")
df2 = pd.read_csv("/Users/luogan/Code/new_push_pull/合成数据_不使用cupy_最简单的版本/MNIST/testgrad_norm,hetero=True,s alpha=0.1, PushPull, lr[0]=0.08, n_nodes=4, batch_size=128, 2025-07-30.csv")

i = "avg_grad_norm"
j = "gradient_norm_on_full_trainset"
end = 60000

plt.plot(df1[i][:end], label="uniform lr")
plt.plot(df2[i][:end], label="vertex lr")
plt.title("avg_grad_norm, mnist, n=4, lr_basic=5e-3")
plt.yscale("log")
plt.grid()
plt.legend()
plt.show()
