# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/home/lg/new_push_pull/合成数据/output_dir/a_inverse_neighbor_c=0.11807027105482834_avg_n=16_gpu_batched.csv")
df2 = pd.read_csv("/home/lg/new_push_pull/合成数据/output_dir/b_inverse_neighbor_c=0.1201267392141204_avg_n=16_gpu_batched.csv")
df3 = pd.read_csv("/home/lg/new_push_pull/合成数据/output_dir/random_max_neighbor_c=0.17072480034308374_avg_n=16_gpu_batched.csv")
df4 = pd.read_csv("/home/lg/new_push_pull/合成数据/output_dir/uniform_neighbor_c=0.15034196632550306_avg_n=16_gpu_batched.csv")
df5 = pd.read_csv("/home/lg/new_push_pull/合成数据/output_dir/vertex_max_neighbor_c=0.36127040046844183_avg_n=16_gpu_batched.csv")
df6 = pd.read_csv("/home/lg/new_push_pull/合成数据/output_dir/vertex_min_neighbor_c=0.06059360486506529_avg_n=16_gpu_batched.csv")

index = "gradient_norm_on_full_trainset_avg"
end =1000000

# Create two subplots in a 1x2 layout
plt.figure(figsize=(12, 6))

# First subplot
plt.subplot(1, 2, 1)
plt.plot(df6["gradient_norm_on_full_trainset_avg"][:end], label="vertex_min_neighbor, c=0.060") 
plt.plot(df1["gradient_norm_on_full_trainset_avg"][:end], label="a_inverse_neighbor, c=0.118")
plt.plot(df2["gradient_norm_on_full_trainset_avg"][:end], label="b_inverse_neighbor, c=0.120")
plt.plot(df4["gradient_norm_on_full_trainset_avg"][:end], label="uniform_neighbor, c=0.150")
plt.plot(df3["gradient_norm_on_full_trainset_avg"][:end], label="random_max_neighbor, c=0.170")
plt.plot(df5["gradient_norm_on_full_trainset_avg"][:end], label="vertex_max_neighbor, c=0.361") 
plt.legend()  
plt.title("Gradient Norm on Full Trainset Avg")
plt.yscale("log")

# Second subplot
plt.subplot(1, 2, 2)
plt.plot(df6["loss_on_full_trainset_avg"][:end], label="vertex_min_neighbor, c=0.060") 
plt.plot(df1["loss_on_full_trainset_avg"][:end], label="a_inverse_neighbor, c=0.118")
plt.plot(df2["loss_on_full_trainset_avg"][:end], label="b_inverse_neighbor, c=0.120")
plt.plot(df4["loss_on_full_trainset_avg"][:end], label="uniform_neighbor, c=0.150")
plt.plot(df3["loss_on_full_trainset_avg"][:end], label="random_max_neighbor, c=0.170")
plt.plot(df5["loss_on_full_trainset_avg"][:end], label="vertex_max_neighbor, c=0.361") 
plt.legend()  
plt.title("Loss on Full Trainset Avg")
plt.yscale("log")

plt.tight_layout()

plt.suptitle("nrearest neighbor", fontsize=16, y=1.05)
plt.show()

# %%
df1 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero/a_inverse_neighbor_hetero_alpha0.1_c=0.11807027105482834_avg_n=16_gpu_batched.csv")
df2 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero/b_inverse_neighbor_hetero_alpha0.1_c=0.1201267392141204_avg_n=16_gpu_batched.csv")
df3 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero/random_max_neighbor_hetero_alpha0.1_c=0.17072480034308374_avg_n=16_gpu_batched.csv")
df4 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero/uniform_neighbor_hetero_alpha0.1_c=0.15034196632550306_avg_n=16_gpu_batched.csv")
df5 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero/vertex_max_neighbor_hetero_alpha0.1_c=0.36127040046844183_avg_n=16_gpu_batched.csv")
df6 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero/vertex_min_neighbor_hetero_alpha0.1_c=0.06059360486506529_avg_n=16_gpu_batched.csv")

index = "gradient_norm_on_full_trainset_avg"
end =1000000

# Create two subplots in a 1x2 layout
plt.figure(figsize=(12, 6))

# First subplot
plt.subplot(1, 2, 1)
plt.plot(df6["gradient_norm_on_full_trainset_avg"][:end], label="vertex_min_neighbor, c=0.060") 
plt.plot(df1["gradient_norm_on_full_trainset_avg"][:end], label="a_inverse_neighbor, c=0.118")
plt.plot(df2["gradient_norm_on_full_trainset_avg"][:end], label="b_inverse_neighbor, c=0.120")
plt.plot(df4["gradient_norm_on_full_trainset_avg"][:end], label="uniform_neighbor, c=0.150")
plt.plot(df3["gradient_norm_on_full_trainset_avg"][:end], label="random_max_neighbor, c=0.170")
plt.plot(df5["gradient_norm_on_full_trainset_avg"][:end], label="vertex_max_neighbor, c=0.361") 
plt.legend()  
plt.title("Gradient Norm on Full Trainset Avg")
plt.yscale("log")

# Second subplot
plt.subplot(1, 2, 2)
plt.plot(df6["loss_on_full_trainset_avg"][:end], label="vertex_min_neighbor, c=0.060") 
plt.plot(df1["loss_on_full_trainset_avg"][:end], label="a_inverse_neighbor, c=0.118")
plt.plot(df2["loss_on_full_trainset_avg"][:end], label="b_inverse_neighbor, c=0.120")
plt.plot(df4["loss_on_full_trainset_avg"][:end], label="uniform_neighbor, c=0.150")
plt.plot(df3["loss_on_full_trainset_avg"][:end], label="random_max_neighbor, c=0.170")
plt.plot(df5["loss_on_full_trainset_avg"][:end], label="vertex_max_neighbor, c=0.361") 
plt.legend()  
plt.title("Loss on Full Trainset Avg")
plt.yscale("log")

plt.tight_layout()

plt.suptitle("nearest neighbor, hetero", fontsize=16, y=1.05)
plt.show()

# %%
df1 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero_full/a_inverse_neighbor_hetero_alpha0.1_c=0.11807027105482834_avg_n=16_gpu_batched.csv")
df2 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero_full/b_inverse_neighbor_hetero_alpha0.1_c=0.1201267392141204_avg_n=16_gpu_batched.csv")
df3 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero_full/random_max_neighbor_hetero_alpha0.1_c=0.17072480034308374_avg_n=16_gpu_batched.csv")
df4 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero_full/uniform_neighbor_hetero_alpha0.1_c=0.15034196632550306_avg_n=16_gpu_batched.csv")
df5 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero_full/vertex_max_neighbor_hetero_alpha0.1_c=0.36127040046844183_avg_n=16_gpu_batched.csv")
df6 = pd.read_csv("/home/lg/new_push_pull/合成数据/hetero_full/vertex_min_neighbor_hetero_alpha0.1_c=0.06059360486506529_avg_n=16_gpu_batched.csv")

index = "gradient_norm_on_full_trainset_avg"
end =1000000

# Create two subplots in a 1x2 layout
plt.figure(figsize=(12, 6))

# First subplot
plt.subplot(1, 2, 1)
plt.plot(df6["gradient_norm_on_full_trainset_avg"][:end], label="vertex_min_neighbor, c=0.060") 
plt.plot(df1["gradient_norm_on_full_trainset_avg"][:end], label="a_inverse_neighbor, c=0.118")
plt.plot(df2["gradient_norm_on_full_trainset_avg"][:end], label="b_inverse_neighbor, c=0.120")
plt.plot(df4["gradient_norm_on_full_trainset_avg"][:end], label="uniform_neighbor, c=0.150")
plt.plot(df3["gradient_norm_on_full_trainset_avg"][:end], label="random_max_neighbor, c=0.170")
plt.plot(df5["gradient_norm_on_full_trainset_avg"][:end], label="vertex_max_neighbor, c=0.361") 
plt.legend()  
plt.title("Gradient Norm on Full Trainset Avg")
plt.yscale("log")

# Second subplot
plt.subplot(1, 2, 2)
plt.plot(df6["loss_on_full_trainset_avg"][:end], label="vertex_min_neighbor, c=0.060") 
plt.plot(df1["loss_on_full_trainset_avg"][:end], label="a_inverse_neighbor, c=0.118")
plt.plot(df2["loss_on_full_trainset_avg"][:end], label="b_inverse_neighbor, c=0.120")
plt.plot(df4["loss_on_full_trainset_avg"][:end], label="uniform_neighbor, c=0.150")
plt.plot(df3["loss_on_full_trainset_avg"][:end], label="random_max_neighbor, c=0.170")
plt.plot(df5["loss_on_full_trainset_avg"][:end], label="vertex_max_neighbor, c=0.361") 
plt.legend()  
plt.title("Loss on Full Trainset Avg")
plt.yscale("log")

plt.tight_layout()

plt.suptitle("hetero_full", fontsize=16, y=1.05)
plt.show()
